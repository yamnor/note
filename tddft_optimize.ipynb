# %% [markdown]
# <a href="https://colab.research.google.com/github/yamnor/gamess-howto/blob/main/tddft_optimize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt

# %%
energy = []
for n in range(4):
  energy.append([float(line.split()[2]) for line in open('output.txt', 'r').readlines() if ' %d  A '%(n) in line])

# %%
x = list(range(len(energy[0])))
fig, ax = plt.subplots()
ax.plot(x, energy[2], label="S0")
ax.plot(x, energy[3], label="S1")
ax.set_xlabel("Step")
ax.set_ylabel("Energy [au]")
ax.legend()
plt.show()

# %%
fig.savefig('energy.png')
